# %% [markdown]
# ### Problem Statement
# - Using NLTK's Inaugural Address (inaugural) corpus, create three keyword-based document retrieval systems. The corpus consists of inaugural addresses made by U.S presidents upon assuming office.
#
# #### Requirements
# - The system should take keywords from user and return the most relevant inaugural speeches (a maximum of 5) based on the keywords.
# - The matches need not be verbatim.
# - The system should return results with the matching regions highlighted.
# - Build three IR systems based on TF-IDF Vectorization, Binary Independence Model and a custom model created by you.
# - Run the following keywords on all three systems and report the results. Compare the results and write your observations. You can also use your own keyword combinations in addition to the ones mentioned below:
#   - freedom, jobs
#   - slavery, war
#   - liberty, slavery
#   - freedom, military

# %%
#importing libraries
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import nltk
import string
import numpy as np
import copy
import pandas as pd
import math
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import defaultdict
from math import log, sqrt
from copy import deepcopy

# %%
#loading inaugural speeches data 
speeches = nltk.corpus.inaugural.fileids()
speeches
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
#  '1957-Eisenhower.txt',
#  '1961-Kennedy.txt',
#  '1965-Johnson.txt',
#  '1969-Nixon.txt',
#  '1973-Nixon.txt',
#  '1977-Carter.txt',
#  '1981-Reagan.txt',
#  '1985-Reagan.txt',
#  '1989-Bush.txt',
#  '1993-Clinton.txt',
#  '1997-Clinton.txt',
#  '2001-Bush.txt',
#  '2005-Bush.txt',
#  '2009-Obama.txt',
#  '2013-Obama.txt',
#  '2017-Trump.txt']

# %%
#reading required data and storing in a dictionary
from nltk.corpus import inaugural
speeches_dict = {}
for speech in speeches:
    speeches_dict[speech] = inaugural.raw(speech)

# %%
speeches_dict['1793-Washington.txt']
# Out:
# 'Fellow citizens, I am again called upon by the voice of my country to execute the functions of its Chief Magistrate. When the occasion proper for it shall arrive, I shall endeavor to express the high sense I entertain of this distinguished honor, and of the confidence which has been reposed in me by the people of united America.\n\nPrevious to the execution of any official act of the President the Constitution requires an oath of office. This oath I am now about to take, and in your presence: That if it shall be found during my administration of the Government I have in any instance violated willingly or knowingly the injunctions thereof, I may (besides incurring constitutional punishment) be subject to the upbraidings of all who are now witnesses of the present solemn ceremony.\n\n \n'

# %% [markdown]
# ### preprocessing:

# %%
#function to convert into lowercase
def lower_case(text):
    return text.lower()

# %%
#function to remove whitespace characters
def remove_white_space(text):
    return text.replace('\n','').replace('\t','').replace('\r','')

# %%
#function to remove stopwords
def stopwords_removal(text):
    stop_words = stopwords.words('english')
    words = word_tokenize(text)
    new_text = ""
    for word in words:
        if word not in stop_words and len(word) > 1:
            new_text = new_text + " " + word
    return new_text

# %%
#function to remove punctuations
def remove_punctuation(text):
    symbols = "!\"#$%&()*+-''./:;<=>?@[\]^_`{|}~"
    for i in range(len(symbols)):
        text = text.replace(symbols[i], "")
    return text

# %%
# function for preprocessing data
def preprocess(text):
    text = lower_case(text)
    text = remove_white_space(text)
    text = remove_punctuation(text)
    text = stopwords_removal(text)
    return text

# %%
#storing preprocessed in a dict
preprocessed_dict = {}
for key in list(speeches_dict.keys()):
    preprocessed_dict[key] = preprocess(speeches_dict[key])

# %% [markdown]
# ## TF-IDF:

# %%
## Create Vocabulary
vocabulary = set()
for doc in preprocessed_dict.values():
    vocabulary.update(doc.split(' '))
vocabulary = list(vocabulary)

# %%
# Intializating the tfIdf model
tfidf = TfidfVectorizer(vocabulary=vocabulary)

# %%
# Transform the TfIdf model
tfidf.fit(list(preprocessed_dict.values()))
tfidf_tran=tfidf.transform(preprocessed_dict.values())

# %%
#creating dataframe for tfidf values
tfidf_pd = pd.DataFrame(tfidf_tran.A)
tfidf_pd.columns = vocabulary

# %%
#function to highlight the matching regions
def highlight(text,word):
    if text.find(word) > 0:
        idx = text.find(word)
        end_idx = idx + text[idx:].find(" ")
        new_str = text[:idx]+'\x1b[1;31m'+ text[idx:end_idx]+'\x1b[0m'
        if text[:end_idx].find(word) > 0:
            return new_str+" " + highlight(text[:end_idx],word)
        else:
            return new_str+" " + text[:end_idx]

# %%
#extracting highlighted matching regions
def display_highlight(df,words):
    text = df['Data'][0]
    sentances = sent_tokenize(text)
    for sent in sentances:
        highlighted_str = highlight(sent,words[0])
        if highlighted_str is None:
            highlighted_str2 = highlight(sent,words[1])
        else:
            highlighted_str2 = highlight(highlighted_str,words[1])
        if highlighted_str2 is not None:
            print(highlighted_str2)
        elif highlighted_str is not None :
            print(highlighted_str)

# %%
#finding tfidf scores and storing top 5 relevant documents in a dataframe
def get_TFIDF_Score(df,user_words):
    new_df = pd.DataFrame(df[user_words[0]]+df[user_words[1]])
    new_df = new_df.sort_values([0],ascending=False).head()
    index = new_df.index.values
    
    df = pd.DataFrame()
    for i in range(len(index)):
        df.loc[i,'File'] = list(preprocessed_dict.keys())[index[i]]
        df.loc[i,'Data'] = list(speeches_dict.values())[index[i]]
        df.loc[i,'Score'] = new_df[0][index[i]]
    return df
#displaying final results
def user_query(user_words):
    df = get_TFIDF_Score(tfidf_pd,user_words)
    display(df)
    display_highlight(df,user_words)

# %%
#taking number of queries from user
n = int(input("Number of queries: "))
n_queries = []
#taking queries from user
for i in range(n):
    n_queries.append(list(map(str,input("Enter a query:").split(" "))))
for query in n_queries:
    print(f"\n\nTop 5 relevant documents for given query {query}:")
    #calling the function to print final results
    user_query(query)
# Out:
# Number of queries: 4
# Enter a query:freedom jobs
# Enter a query:slavery war
# Enter a query:liberty slavery
# Enter a query:freedom military
#
#
# Top 5 relevant documents for given query ['freedom', 'jobs']:
#                   File                                               Data  \
# 0        2005-Bush.txt  Vice President Cheney, Mr. Chief Justice, Pres...
# 1  1957-Eisenhower.txt  The Price of Peace\nMr. Chairman, Mr. Vice Pre...
# 2       2017-Trump.txt  Chief Justice Roberts, President Carter, Presi...
# 3      1985-Reagan.txt  Senator Mathias, Chief Justice Burger, Vice Pr...
# 4      1949-Truman.txt  Mr. Vice President, Mr. Chief Justice, and fel...
#
#       Score
# 0  0.339238
# 1  0.156350
# 2  0.134013
# 3  0.131705
# 4  0.129353
# For a half a century, America defended our own freedom For a half a century, America defended our own  For a half a century, America defended our own
# There is only one force of history that can break the reign of hatred and resentment, and expose the pretensions of tyrants, and reward the hopes of the decent and tolerant, and that is the force of human  There is only one force of history that can break the reign of hatred and resentment, and expose the pretensions of tyrants, and reward the hopes of the decent and tolerant, and that is the force of human
# The best hope for peace in our world is the expansion of freedom The best hope for peace in our world is the expansion of  The best hope for peace in our world is the expansion of
# Our goal instead is to help others find their own voice, attain their own freedom, Our goal instead is to help others find their own voice, attain their own  Our goal instead is to help others find their own voice, attain their own
# America¡¦s influence is not unlimited, but fortunately for the oppressed, America¡¦s influence is considerable, and we will use it confidently in freedom¡¦s America¡¦s influence is not unlimited, but fortunately for the oppressed, America¡¦s influence is considerable, and we will use it confidently in  America¡¦s influence is not unlimited, but fortunately for the oppressed, America¡¦s influence is considerable, and we will use it confidently in
# We will persistently clarify the choice before every ruler and every nation: The moral choice between oppression, which is always wrong, and freedom, We will persistently clarify the choice before every ruler and every nation: The moral choice between oppression, which is always wrong, and  We will persistently clarify the choice before every ruler and every nation: The moral choice between oppression, which is always wrong, and
# In the long run, there is no justice without freedom, In the long run, there is no justice without  In the long run, there is no justice without
# Some, I know, have questioned the global appeal of liberty¡Xthough this time in history, four decades defined by the swiftest advance of freedom Some, I know, have questioned the global appeal of liberty¡Xthough this time in history, four decades defined by the swiftest advance of  Some, I know, have questioned the global appeal of liberty¡Xthough this time in history, four decades defined by the swiftest advance of
# Eventually, the call of freedom Eventually, the call of  Eventually, the call of
# The rulers of outlaw regimes can know that we still believe as Abraham Lincoln did: ¡§Those who deny freedom The rulers of outlaw regimes can know that we still believe as Abraham Lincoln did: ¡§Those who deny  The rulers of outlaw regimes can know that we still believe as Abraham Lincoln did: ¡§Those who deny
# Division among free nations is a primary goal of freedom¡¦s Division among free nations is a primary goal of  Division among free nations is a primary goal of
# Yet because we have acted in the great liberating tradition of this nation, tens of millions have achieved their  Yet because we have acted in the great liberating tradition of this nation, tens of millions have achieved their
# It warms those who feel its power, it burns those who fight its progress, and one day this untamed fire of freedom It warms those who feel its power, it burns those who fight its progress, and one day this untamed fire of  It warms those who feel its power, it burns those who fight its progress, and one day this untamed fire of
# America has need of idealism and courage, because we have essential work at home¡Xthe unfinished work of American  America has need of idealism and courage, because we have essential work at home¡Xthe unfinished work of American
# In America¡¦s ideal of freedom, In America¡¦s ideal of  In America¡¦s ideal of
# By making every citizen an agent of his or her own destiny, we will give our fellow Americans greater freedom By making every citizen an agent of his or her own destiny, we will give our fellow Americans greater  By making every citizen an agent of his or her own destiny, we will give our fellow Americans greater
# In America¡¦s ideal of freedom, In America¡¦s ideal of  In America¡¦s ideal of
# In America¡¦s ideal of freedom, In America¡¦s ideal of  In America¡¦s ideal of
# And our country must abandon all the habits of racism, because we cannot carry the message of freedom And our country must abandon all the habits of racism, because we cannot carry the message of  And our country must abandon all the habits of racism, because we cannot carry the message of
# Did our generation advance the cause of  Did our generation advance the cause of
# These questions that judge us also unite us, because Americans of every party and background, Americans by choice and by birth, are bound to one another in the cause of  These questions that judge us also unite us, because Americans of every party and background, Americans by choice and by birth, are bound to one another in the cause of
# We felt the unity and fellowship of our nation when freedom We felt the unity and fellowship of our nation when  We felt the unity and fellowship of our nation when
# We go forward with complete confidence in the eventual triumph of  We go forward with complete confidence in the eventual triumph of
# We have confidence because freedom We have confidence because  We have confidence because
# Renewed in our strength¡Xtested, but not weary¡Xwe are ready for the greatest achievements in the history of  Renewed in our strength¡Xtested, but not weary¡Xwe are ready for the greatest achievements in the history of
#
#
# Top 5 relevant documents for given query ['slavery', 'war']:
#                 File                                               Data  \
# 0   1865-Lincoln.txt  Fellow-Countrymen:\n\nAt this second appearing...
# 1   1813-Madison.txt  About to add the solemnity of an oath to the o...
# 2  1857-Buchanan.txt  Fellow citizens, I appear before you this day ...
# 3  1881-Garfield.txt  Fellow-Citizens:\n\nWe stand to-day upon an em...
# 4    1821-Monroe.txt  Fellow citizens, I shall not attempt to descri...
#
#       Score
# 0  0.280064
# 1  0.232751
# 2  0.154216
# 3  0.120977
# 4  0.109167
# On the occasion corresponding to this four years ago all thoughts were anxiously directed to an impending civil  On the occasion corresponding to this four years ago all thoughts were anxiously directed to an impending civil
# While the inaugural address was being delivered from this place, devoted altogether to saving the Union without war, While the inaugural address was being delivered from this place, devoted altogether to saving the Union without  While the inaugural address was being delivered from this place, devoted altogether to saving the Union without
# Both parties deprecated war, Both parties deprecated  Both parties deprecated
# All knew that this interest was somehow the cause of the  All knew that this interest was somehow the cause of the
# To strengthen, perpetuate, and extend this interest was the object for which the insurgents would rend the Union even by war, To strengthen, perpetuate, and extend this interest was the object for which the insurgents would rend the Union even by  To strengthen, perpetuate, and extend this interest was the object for which the insurgents would rend the Union even by
# Neither party expected for the war Neither party expected for the  Neither party expected for the
# If we shall suppose that American slavery If we shall suppose that American  If we shall suppose that American
# Fondly do we hope, fervently do we pray, that this mighty scourge of war Fondly do we hope, fervently do we pray, that this mighty scourge of  Fondly do we hope, fervently do we pray, that this mighty scourge of
# With malice toward With malice to With malice t
#
#
# Top 5 relevant documents for given query ['liberty', 'slavery']:
#                 File                                               Data  \
# 0      2005-Bush.txt  Vice President Cheney, Mr. Chief Justice, Pres...
# 1  1857-Buchanan.txt  Fellow citizens, I appear before you this day ...
# 2  1881-Garfield.txt  Fellow-Citizens:\n\nWe stand to-day upon an em...
# 3   1833-Jackson.txt  Fellow citizens, the will of the American peop...
# 4  1841-Harrison.txt  Called from a retirement which I had supposed ...
#
#       Score
# 0  0.194388
# 1  0.128028
# 2  0.124289
# 3  0.076645
# 4  0.076322
# We felt the unity and fellowship of our nation when freedom We felt the unity and fellowship of our nation when  We felt the unity and fellowship of our nation when
# We go forward with complete confidence in the eventual triumph of  We go forward with complete confidence in the eventual triumph of
# We have confidence because freedom We have confidence because  We have confidence because
# Renewed in our strength¡Xtested, but not weary¡Xwe are ready for the greatest achievements in the history of  Renewed in our strength¡Xtested, but not weary¡Xwe are ready for the greatest achievements in the history of

# %% [markdown]
# ## Binary independence model:

# %%
#finding inverted index for each term(the documents in which the term appeared)
def inverted_index(corpus):
    index = defaultdict(set)
    for docid, article in enumerate(corpus):
        for term in article.split(" "):
            index[term].add(docid)
    return index

# %%
#union of all the documents containing all the query words
def posting_lists_union(pl1, pl2):
        pl1 = sorted(list(pl1))
        pl2 = sorted(list(pl2))
        union = []
        i = 0
        j = 0
        while (i < len(pl1) and j < len(pl2)):
            if (pl1[i] == pl2[j]):
                union.append(pl1[i])
                i += 1
                j += 1
            elif (pl1[i] < pl2[j]):
                union.append(pl1[i])
                i += 1
            else:
                union.append(pl2[j])
                j += 1
        for k in range(i, len(pl1)):
            union.append(pl1[k])
        for k in range(j, len(pl2)):
            union.append(pl2[k])
        return union

# %%
#finding document frequency
def DF(term, index):
    return len(index[term])

#finding inverse document frequency
def IDF(term, index, corpus):
    return log(len(corpus)/DF(term, index))

#calculating RSV weights for each term using df and idf
def RSV_weights(corpus,index):
    N = len(corpus)
    w = {}
    for term in index.keys():
        p = DF(term, index)/(N+0.5)  
        w[term] = IDF(term, index, corpus) + log(p/(1-p))
    return w

# %%
#creating a class for the model
class BIM():
    #initialising the objects
    def __init__(self, corpus):
        self.original_corpus = deepcopy(corpus)
        self.articles = corpus
        self.index = inverted_index(self.articles)
        self.weights = RSV_weights(self.articles, self.index)
        self.ranked = []
        self.query_text = ''
   #finding scores of documents using rsv weights
    def RSV_doc_query(self, doc_id, query):
        score = 0
        doc = self.articles[doc_id]
        for term in doc.split(" "):
            if term in query:
                score += self.weights[term]     
        return score
    #ranking the documents based on scores
    def ranking(self, query):
        docs = []
        for term in self.index: 
            if term in query:
                docs = posting_lists_union(docs, self.index[term])
        scores = []
        for doc in docs:
            scores.append((doc, self.RSV_doc_query(doc, query)))
        self.ranked = sorted(scores, key=lambda x: x[1], reverse = True)
        return self.ranked

    # displaying top 5 relevant documents in a dataframe
    def user_query(self, query):
        ranking = self.ranking(query)
        n = 5
        df = pd.DataFrame()
        for i in range(n):
            df.loc[i,'File'] = list(preprocessed_dict.keys())[ranking[i][0]]
            df.loc[i,'Data'] = list(speeches_dict.values())[ranking[i][0]]
            df.loc[i,'Score'] = ranking[i][1]
        display(df)
        #highlighting the matching regions in the relevant documents
        display_highlight(df,query)
        self.weights = RSV_weights(self.articles, self.index)

# %%
#calling the model for a query
def user_query_bim(user_words):
    bim  = BIM(list(preprocessed_dict.values()))
    bim.user_query(user_words)

# %%
#user input for number of queries
n = int(input("Number of queries: "))
n_queries = []
#queries from user
for i in range(n):
    n_queries.append(list(map(str,input("Enter a query:").split(" "))))
#top 5 relevant documents for each query
for query in n_queries:
    print(f"\n\nTop 5 relevant documents for given query {query}:")
    user_query_bim(query)
# Out:
# Number of queries: 4
# Enter a query:freedom jobs
# Enter a query:slavery war
# Enter a query:liberty slavery
# Enter a query:freedom military
#
#
# Top 5 relevant documents for given query ['freedom', 'jobs']:
#                   File                                               Data  \
# 0        2005-Bush.txt  Vice President Cheney, Mr. Chief Justice, Pres...
# 1      1985-Reagan.txt  Senator Mathias, Chief Justice Burger, Vice Pr...
# 2      1949-Truman.txt  Mr. Vice President, Mr. Chief Justice, and fel...
# 3  1957-Eisenhower.txt  The Price of Peace\nMr. Chairman, Mr. Vice Pre...
# 4  1953-Eisenhower.txt  My friends, before I begin the expression of t...
#
#        Score
# 0  22.726265
# 1  11.363132
# 2  10.416205
# 3   9.469277
# 4   7.575422
# For a half a century, America defended our own freedom For a half a century, America defended our own  For a half a century, America defended our own
# There is only one force of history that can break the reign of hatred and resentment, and expose the pretensions of tyrants, and reward the hopes of the decent and tolerant, and that is the force of human  There is only one force of history that can break the reign of hatred and resentment, and expose the pretensions of tyrants, and reward the hopes of the decent and tolerant, and that is the force of human
# The best hope for peace in our world is the expansion of freedom The best hope for peace in our world is the expansion of  The best hope for peace in our world is the expansion of
# Our goal instead is to help others find their own voice, attain their own freedom, Our goal instead is to help others find their own voice, attain their own  Our goal instead is to help others find their own voice, attain their own
# America¡¦s influence is not unlimited, but fortunately for the oppressed, America¡¦s influence is considerable, and we will use it confidently in freedom¡¦s America¡¦s influence is not unlimited, but fortunately for the oppressed, America¡¦s influence is considerable, and we will use it confidently in  America¡¦s influence is not unlimited, but fortunately for the oppressed, America¡¦s influence is considerable, and we will use it confidently in
# We will persistently clarify the choice before every ruler and every nation: The moral choice between oppression, which is always wrong, and freedom, We will persistently clarify the choice before every ruler and every nation: The moral choice between oppression, which is always wrong, and  We will persistently clarify the choice before every ruler and every nation: The moral choice between oppression, which is always wrong, and
# In the long run, there is no justice without freedom, In the long run, there is no justice without  In the long run, there is no justice without
# Some, I know, have questioned the global appeal of liberty¡Xthough this time in history, four decades defined by the swiftest advance of freedom Some, I know, have questioned the global appeal of liberty¡Xthough this time in history, four decades defined by the swiftest advance of  Some, I know, have questioned the global appeal of liberty¡Xthough this time in history, four decades defined by the swiftest advance of
# Eventually, the call of freedom Eventually, the call of  Eventually, the call of
# The rulers of outlaw regimes can know that we still believe as Abraham Lincoln did: ¡§Those who deny freedom The rulers of outlaw regimes can know that we still believe as Abraham Lincoln did: ¡§Those who deny  The rulers of outlaw regimes can know that we still believe as Abraham Lincoln did: ¡§Those who deny
# Division among free nations is a primary goal of freedom¡¦s Division among free nations is a primary goal of  Division among free nations is a primary goal of
# Yet because we have acted in the great liberating tradition of this nation, tens of millions have achieved their  Yet because we have acted in the great liberating tradition of this nation, tens of millions have achieved their
# It warms those who feel its power, it burns those who fight its progress, and one day this untamed fire of freedom It warms those who feel its power, it burns those who fight its progress, and one day this untamed fire of  It warms those who feel its power, it burns those who fight its progress, and one day this untamed fire of
# America has need of idealism and courage, because we have essential work at home¡Xthe unfinished work of American  America has need of idealism and courage, because we have essential work at home¡Xthe unfinished work of American
# In America¡¦s ideal of freedom, In America¡¦s ideal of  In America¡¦s ideal of
# By making every citizen an agent of his or her own destiny, we will give our fellow Americans greater freedom By making every citizen an agent of his or her own destiny, we will give our fellow Americans greater  By making every citizen an agent of his or her own destiny, we will give our fellow Americans greater
# In America¡¦s ideal of freedom, In America¡¦s ideal of  In America¡¦s ideal of
# In America¡¦s ideal of freedom, In America¡¦s ideal of  In America¡¦s ideal of
# And our country must abandon all the habits of racism, because we cannot carry the message of freedom And our country must abandon all the habits of racism, because we cannot carry the message of  And our country must abandon all the habits of racism, because we cannot carry the message of
# Did our generation advance the cause of  Did our generation advance the cause of
# These questions that judge us also unite us, because Americans of every party and background, Americans by choice and by birth, are bound to one another in the cause of  These questions that judge us also unite us, because Americans of every party and background, Americans by choice and by birth, are bound to one another in the cause of
# We felt the unity and fellowship of our nation when freedom We felt the unity and fellowship of our nation when  We felt the unity and fellowship of our nation when
# We go forward with complete confidence in the eventual triumph of  We go forward with complete confidence in the eventual triumph of
# We have confidence because freedom We have confidence because  We have confidence because
# Renewed in our strength¡Xtested, but not weary¡Xwe are ready for the greatest achievements in the history of  Renewed in our strength¡Xtested, but not weary¡Xwe are ready for the greatest achievements in the history of
#
#
# Top 5 relevant documents for given query ['slavery', 'war']:
#                File                                               Data  \
# 0   1821-Monroe.txt  Fellow citizens, I shall not attempt to descri...
# 1  1813-Madison.txt  About to add the solemnity of an oath to the o...
# 2  1921-Harding.txt  My Countrymen:\n\nWhen one surveys the world a...
# 3  1865-Lincoln.txt  Fellow-Countrymen:\n\nAt this second appearing...
# 4   1817-Monroe.txt  I should be destitute of feeling if I was not ...
#
#        Score
# 0  23.324053
# 1  20.408547
# 2  18.950793
# 3  16.235000
# 4  14.577533
# In America¡¦s ideal of freedom, In America¡¦s ideal of  In America¡¦s ideal of
# In America¡¦s ideal of freedom, In America¡¦s ideal of  In America¡¦s ideal of
# And our country must abandon all the habits of racism, because we cannot carry the message of freedom And our country must abandon all the habits of racism, because we cannot carry the message of  And our country must abandon all the habits of racism, because we cannot carry the message of
# Did our generation advance the cause of  Did our generation advance the cause of
# These questions that judge us also unite us, because Americans of every party and background, Americans by choice and by birth, are bound to one another in the cause of  These questions that judge us also unite us, because Americans of every party and background, Americans by choice and by birth, are bound to one another in the cause of
# We felt the unity and fellowship of our nation when freedom We felt the unity and fellowship of our nation when  We felt the unity and fellowship of our nation when
# We go forward with complete confidence in the eventual triumph of  We go forward with complete confidence in the eventual triumph of
# We have confidence because freedom We have confidence because  We have confidence because
# Renewed in our strength¡Xtested, but not weary¡Xwe are ready for the greatest achievements in the history of  Renewed in our strength¡Xtested, but not weary¡Xwe are ready for the greatest achievements in the history of

# %% [markdown]
# ### Custom model:

# %%
#function for custom model
def customModel(words):
    #declaring a dictionary
    word_dict = {}
    #finding query words frequency in each document
    for word in words:
       
        word_dict[word] = {}
        #iterating for each document
        for key in list(preprocessed_dict.keys()):
            #iterating for each word in a document
            for text in preprocessed_dict[key].split(" "):
                #if the query word is present in document,increase the count
                if word == text:
                    
                    if key in word_dict[word]:
                        word_dict[word][key] += 1
                    else:
                        word_dict[word][key] = 1
    #sorting the documents based on query word frequencies                    
    for word in words:
        word_dict[word] = dict(sorted(word_dict[word].items(), key=lambda item:item[1],reverse=True))
    results = {}
    #finding the top documents in sorted dictionaries which are containing all the query words
    for key1 in list(word_dict[words[0]].keys()):
        for key2 in list(word_dict[words[1]].keys()):
            if key1 == key2:
                #adding the total count of all the query words in each documents
                results[key1] = word_dict[words[0]][key1] + word_dict[words[1]][key1]
    #sorting the documents based on above total count
    results = dict(sorted(results.items(), key=lambda item:item[1],reverse=True))
    #creating a dataframe to display top 5 relevant documents
    df = pd.DataFrame()
    data = []
    for key in list(results.keys()):
        data.append(speeches_dict[key])
    df['File'] = list(results.keys())
    df['Data'] = data
    return df.head()

# %%
#function to display final relevant documents with highlighted regions
def user_query_custom_model(user_words):
    df = customModel(user_words)
    display(df)
    display_highlight(df,user_words)

# %%
#user input for number of queries
n = int(input("Number of queries: "))
n_queries = []
#queries from user
for i in range(n):
    n_queries.append(list(map(str,input("Enter a query:").split(" "))))
#finding relevant documents for each query
for query in n_queries:
    print(f"\n\nTop 5 relevant documents for given query {query}:")
    user_query_custom_model(query)
# Out:
# Number of queries: 4
# Enter a query:freedom jobs
# Enter a query:slavery war
# Enter a query:liberty slavery
# Enter a query:freedom military
#
#
# Top 5 relevant documents for given query ['freedom', 'jobs']:
#                File                                               Data
# 0    2013-Obama.txt  Thank you. Thank you so much.\n\nVice Presiden...
# 1   1981-Reagan.txt  Senator Hatfield, Mr. Chief Justice, Mr. Presi...
# 2    2009-Obama.txt  My fellow citizens:\n\nI stand here today humb...
# 3  1993-Clinton.txt  My fellow citizens, today we celebrate the mys...
# For history tells us that while these truths may be self-evident, they've never been self-executing; that while freedom For history tells us that while these truths may be self-evident, they've never been self-executing; that while  For history tells us that while these truths may be self-evident, they've never been self-executing; that while
# But we have always understood that when times change, so must we; that fidelity to our founding principles requires new responses to new challenges; that preserving our individual freedoms But we have always understood that when times change, so must we; that fidelity to our founding principles requires new responses to new challenges; that preserving our individual  But we have always understood that when times change, so must we; that fidelity to our founding principles requires new responses to new challenges; that preserving our individual
# No single person can train all the math and science teachers we'll need to equip our children for the future, or build the roads and networks and research labs that will bring new jobs No single person can train all the math and science teachers we'll need to equip our children for the future, or build the roads and networks and research labs that will bring new  No single person can train all the math and science teachers we'll need to equip our children for the future, or build the roads and networks and research labs that will bring new
# We do not believe that in this country freedom We do not believe that in this country  We do not believe that in this country
# We cannot cede to other nations the technology that will power new jobs We cannot cede to other nations the technology that will power new  We cannot cede to other nations the technology that will power new
# We will support democracy from Asia to Africa, from the Americas to the Middle East, because our interests and our conscience compel us to act on behalf of those who long for  We will support democracy from Asia to Africa, from the Americas to the Middle East, because our interests and our conscience compel us to act on behalf of those who long for
# We, the people, declare today that the most evident of truthsâthat all of us are created equalâis the star that guides us still; just as it guided our forebears through Seneca Falls and Selma and Stonewall; just as it guided all those men and women, sung and unsung, who left footprints along this great Mall, to hear a preacher say that we cannot walk alone; to hear a King proclaim that our individual freedom We, the people, declare today that the most evident of truthsâthat all of us are created equalâis the star that guides us still; just as it guided our forebears through Seneca Falls and Selma and Stonewall; just as it guided all those men and women, sung and unsung, who left footprints along this great Mall, to hear a preacher say that we cannot walk alone; to hear a King proclaim that our individual  We, the people, declare today that the most evident of truthsâthat all of us are created equalâis the star that guides us still; just as it guided our forebears through Seneca Falls and Selma and Stonewall; just as it guided all those men and women, sung and unsung, who left footprints along this great Mall, to hear a preacher say that we cannot walk alone; to hear a King proclaim that our individual
# With common effort and common purpose, with passion and dedication, let us answer the call of history and carry into an uncertain future that precious light of  With common effort and common purpose, with passion and dedication, let us answer the call of history and carry into an uncertain future that precious light of
#
#
# Top 5 relevant documents for given query ['slavery', 'war']:
#                 File                                               Data
# 0   1865-Lincoln.txt  Fellow-Countrymen:\n\nAt this second appearing...
# 1  1857-Buchanan.txt  Fellow citizens, I appear before you this day ...
# 2  1881-Garfield.txt  Fellow-Citizens:\n\nWe stand to-day upon an em...
# 3  1889-Harrison.txt  Fellow-Citizens, there is no constitutional or...
# 4      1909-Taft.txt  My fellow citizens: Anyone who has taken the o...
# On the occasion corresponding to this four years ago all thoughts were anxiously directed to an impending civil  On the occasion corresponding to this four years ago all thoughts were anxiously directed to an impending civil
# While the inaugural address was being delivered from this place, devoted altogether to saving the Union without war, While the inaugural address was being delivered from this place, devoted altogether to saving the Union without  While the inaugural address was being delivered from this place, devoted altogether to saving the Union without
# Both parties deprecated war, Both parties deprecated  Both parties deprecated
# All knew that this interest was somehow the cause of the  All knew that this interest was somehow the cause of the
# To strengthen, perpetuate, and extend this interest was the object for which the insurgents would rend the Union even by war, To strengthen, perpetuate, and extend this interest was the object for which the insurgents would rend the Union even by  To strengthen, perpetuate, and extend this interest was the object for which the insurgents would rend the Union even by
# Neither party expected for the war Neither party expected for the  Neither party expected for the
# If we shall suppose that American slavery If we shall suppose that American  If we shall suppose that American
# Fondly do we hope, fervently do we pray, that this mighty scourge of war Fondly do we hope, fervently do we pray, that this mighty scourge of  Fondly do we hope, fervently do we pray, that this mighty scourge of
# With malice toward With malice to With malice t
#
#
# Top 5 relevant documents for given query ['liberty', 'slavery']:
#                 File                                               Data
# 0      2005-Bush.txt  Vice President Cheney, Mr. Chief Justice, Pres...
# 1  1881-Garfield.txt  Fellow-Citizens:\n\nWe stand to-day upon an em...
# 2  1857-Buchanan.txt  Fellow citizens, I appear before you this day ...
# 3   1861-Lincoln.txt  Fellow-Citizens of the United States: In compl...
# 4  1889-Harrison.txt  Fellow-Citizens, there is no constitutional or...
# We are led, by events and common sense, to one conclusion: The survival of liberty We are led, by events and common sense, to one conclusion: The survival of  We are led, by events and common sense, to one conclusion: The survival of
# In the long run, there is no justice without freedom, and there can be no human rights without human  In the long run, there is no justice without freedom, and there can be no human rights without human
# Some, I know, have questioned the global appeal of liberty¡Xthough Some, I know, have questioned the global appeal of  Some, I know, have questioned the global appeal of
# We do not accept the existence of permanent tyranny because we do not accept the possibility of permanent  We do not accept the existence of permanent tyranny because we do not accept the possibility of permanent
# When you stand for your liberty, When you stand for your  When you stand for your
# In a world moving toward liberty, In a world moving toward  In a world moving toward
# This is the broader definition of liberty This is the broader definition of  This is the broader definition of
# When our Founders declared a new order of the ages; when soldiers died in wave upon wave for a union based on liberty; When our Founders declared a new order of the ages; when soldiers died in wave upon wave for a union based on  When our Founders declared a new order of the ages; when soldiers died in wave upon wave for a union based on
# History has an ebb and flow of justice, but history also has a visible direction, set by liberty History has an ebb and flow of justice, but history also has a visible direction, set by  History has an ebb and flow of justice, but history also has a visible direction, set by
# America, in this young century, proclaims liberty America, in this young century, proclaims  America, in this young century, proclaims
#
#
# Top 5 relevant documents for given query ['freedom', 'military']:
#                   File                                               Data
# 0      1985-Reagan.txt  Senator Mathias, Chief Justice Burger, Vice Pr...
# 1      1949-Truman.txt  Mr. Vice President, Mr. Chief Justice, and fel...
# 2  1957-Eisenhower.txt  The Price of Peace\nMr. Chairman, Mr. Vice Pre...
# 3  1953-Eisenhower.txt  My friends, before I begin the expression of t...
# 4       1825-Adams.txt  In compliance with an usage coeval with the ex...
# By 1980, we knew it was time to renew our faith, to strive with all our strength toward the ultimate in individual freedom By 1980, we knew it was time to renew our faith, to strive with all our strength toward the ultimate in individual  By 1980, we knew it was time to renew our faith, to strive with all our strength toward the ultimate in individual
# We will not rest until every American enjoys the fullness of freedom, We will not rest until every American enjoys the fullness of  We will not rest until every American enjoys the fullness of
# These will be years when Americans have restored their confidence and tradition of progress; when our values of faith, family, work, and neighborhood were restated for a modern age; when our economy was finally freed from government's grip; when we made sincere efforts at meaningful arms reduction, rebuilding our defenses, our economy, and developing new technologies, and helped preserve peace in a troubled world; when Americans courageously supported the struggle for liberty, self-government, and free enterprise throughout the world, and turned the tide of history away from totalitarian darkness and into the warm sunlight of human  These will be years when Americans have restored their confidence and tradition of progress; when our values of faith, family, work, and neighborhood were restated for a modern age; when our economy was finally freed from government's grip; when we made sincere efforts at meaningful arms reduction, rebuilding our defenses, our economy, and developing new technologies, and helped preserve peace in a troubled world; when Americans courageously supported the struggle for liberty, self-government, and free enterprise throughout the world, and turned the tide of history away from totalitarian darkness and into the warm sunlight of human
# Let history say of us, "These were golden years -- when the American Revolution was reborn, when freedom Let history say of us, "These were golden years -- when the American Revolution was reborn, when  Let history say of us, "These were golden years -- when the American Revolution was reborn, when
# -- From new freedom -- From new  -- From new
# Yet history has shown that peace will not come, nor will our freedom Yet history has shown that peace will not come, nor will our  Yet history has shown that peace will not come, nor will our
# There are those in the world who scorn our vision of human dignity and  There are those in the world who scorn our vision of human dignity and
# One nation, the Soviet Union, has conducted the greatest military One nation, the Soviet Union, has conducted the greatest  One nation, the Soviet Union, has conducted the greatest
# Human freedom Human  Human
# America must remain freedom's America must remain  America must remain
# Every victory for human freedom Every victory for human  Every victory for human
# And may He continue to hold us close as we fill the world with our sound -- sound in unity, affection, and love -- one people under God, dedicated to the dream of freedom And may He continue to hold us close as we fill the world with our sound -- sound in unity, affection, and love -- one people under God, dedicated to the dream of  And may He continue to hold us close as we fill the world with our sound -- sound in unity, affection, and love -- one people under God, dedicated to the dream of

# %% [markdown]
# ### Observations:
# #### For the first query with the keywords "freedom,jobs"
#    - For TFIDF,the top 5 relevant documents are:
#          2005-Bush.txt,1857-Buchanan.txt,1881-Garfield,1833-Jackson.txt,1841-Harrison.txt
#    - For BIM,the top 5 relevant documents are:
#          2005-Bush.txt,1985-Reagan.txt,1949-Truman.txt,1957-Eisenhower.txt,1953-Eisenhower.txt
#    - For Custom model,the top 5 relevant documents are:
#          2013-Obama.txt,1981-Reagan.txt,2009-Obama.txt,1993-Clinton.txt
# #### For the second query with the keywords "slavery,war"
#    - For TFIDF,the top 5 relevant documents are:
#          1865-Lincoln.txt,1813-Madison.txt,1857-Buchanan.txt,1881-Garfield.txt,1821-Monroe.txt
#    - For BIM,the top 5 relevant documents are:
#          1821-Monroe.txt,1813-Madison.txt,1921-Harding.txt,1865-Lincoln.txt,1817-Monroe.txt
#    - For Custom model,the top 5 relevant documents are:
#          1865-Lincoln.txt,1857-Buchanan.txt,1881-Garfield.txt,1889-Harrison.txt,1909-Taft.txt
# #### For the third query with the keywords "liberty,slavery"
#    - For TFIDF,the top 5 relevant documents are:
#          2005-Bush.txt,1857-Buchanan.txt,1881-Garfield.txt,1833-Jackson.txt,1841-Harrison.txt
#    - For BIM,the top 5 relevant documents are:
#          1841-Harrison.txt,2005-Bush.txt,1881-Garfield.txt,1901-McKinley.txt,2013-Obama.txt
#    - For Custom model,the top 5 relevant documents are:
#          2005-Bush.txt,1881-Garfield.txt,1857-Buchanan.txt,1861-Lincoln.txt,1889-Harrison.txt
# #### For the fourth query with the keywords "freedom,military"
#    - For TFIDF,the top 5 relevant documents are:
#          2005-Bush.txt,1957-Eisenhower.txt,1985-Reagan.txt,1949-Truman.txt,1953-Eisenhower.txt
#    - For BIM,the top 5 relevant documents are:
#          2005-Bush.txt,1985-Reagan.txt,1949-Truman.txt,1957-Eisenhower.txt,1953-Eisenhower.txt
#    - For Custom model,the top 5 relevant documents are:
#          1985-Reagan.txt,1949-Truman.txt,1957-Eisenhower.txt,1953-Eisenhower.txt,1825-Adams.txt
